# %% [markdown]
# # $ \textbf{Introduction to Functions}$

# %% [markdown]
# - Function: group of statements within  a program that perform as specific task
#     - Usually one task of a large program
#         - Functions can be executed in order to perform overall program task
#     - Known as divide and conquer approach
# - Modularized program: program wherein each task within the program is in its own function

# %% [markdown]
# # Benefits of Modularizing a Program with Functions
# - The benefits of using functions include:
#     - Simpler code
#     - Code reuse
#         - write the code once and call it multiple times
#     - Better testing and debugging
#         - Can test and debug each function individually
#     - Faster development
#     - Easier facilitation of teamwork
#         - Different team members can write different functions

# %% [markdown]
# # Void Functions and Value-Returning Functions
#
# - A void function:
#     - Simply executes the statements it contains and then terminates.
# - A value-returning function:
#     - Executes the statements it contains, and then it returns a value back to the statement that called it.
#         - The input, int, and float functions are examples of value-returning functions.

# %% [markdown]
# # Defining and Calling a Function
#
# - Functions are given names
#     - Function naming rules:
#         - Cannot use keywords as a function name
#         - Cannot contain spaces
#         - First character must be a letter or underscore
#         - All other characters must be a letter, number or underscore
#         - Uppercase and lowercase characters are distinct

# %% [markdown]
# - Function name should be descriptive of the task carried out by the function
#     - Often includes a verb
# - Function definition: specifies what function does
#
#
#
# ```
#  def function_name():
# 		statement
# 		statement
# ```

# %% [markdown]
# # Defining and Calling a Function
#
# - Function header: first line of function
#     - Includes keyword def and function name, followed by parentheses and colon
# - Block: set of statements that belong together as a group
#     - Example: the statements included in a function

# %%
# This program do nothing visibly. Why?


def message():
    print('Hello everyone')
    print('This is a part of Python function')

# %% [markdown]
# If we want to display what is going on in the function we need to call the name of the function. In the previous example we should write out of the function block
#
#
# ```
# message()
# ```

# %%
def message():
    print('Hello everyone')
    print('This is a part of Python function')

# Call the message function.
message()

# %% [markdown]
# ## Defining Multiple Functions and Calling

# %%
def greet():
    print("Hi everybody")
    print("I said hi everybody")
    print("I say it every time")
def greet_again():
    print("Let me try again")
    print("Hi everybody")
def greet_again_again():
    print("Last time hi everybody")


greet_again_again()
greet_again()
greet()
# Out:
# Last time hi everybody
# Let me try again
# Hi everybody
# Hi everybody
# I said hi everybody
# I say it every time

# %% [markdown]
# ![funct1.PNG](data:image/png;base64,...)
#
# ![funct2.PNG](data:image/png;base64,...)
#
# ![funct3.PNG](data:image/png;base64,...)
#
# ![funct4.PNG](data:image/png;base64,...)

# %% [markdown]
# # Check Point
#
# What is a function in Python?
#
# A. A named sequence of statements.
#
# B. Any sequence of statements.
#
# C. A mathematical expression that calculates a value.
#
# D. A statement of the form x = 5 + 4.

# %% [markdown]
# # Main Function
#
# - main function: called when the program starts
#     - Calls other functions when they are needed
#     - Defines the mainline logic of the program

# %%
#Functions that you write can also call other functions you write

# This program has two functions. First we define the main function.



def main():
    print('I have a message for you.')
    message()
    print('Goodbye!')


# Next we define the message function.
def message():
    print('Hello everyone')
    print('This message is in the message function')

# Call the main function.

main()

# %% [markdown]
# # Indentation in Python
#
# - Each block must be indented
#     - Lines in block must begin with the same number of spaces
#         - Use tabs or spaces to indent lines in a block, but not both as this can confuse the Python interpreter
#         - IDLE automatically indents the lines in a block
#     - Blank lines that appear in a block are ignored

# %%
def f():
    print('In function f')
    print('When does this print?')


f()

# %% [markdown]
# ##What will print on the screen when we execute the following code?

# %%
def f():
    print('In function f')

print('When does this print?')
f()

# %% [markdown]
# # Designing a Program to Use Functions

# %%
#This program is written to see the options for a dishwasher


def main():
    # Display the beginning message.
    message()
    input('Press Enter to see option 1.')
    # Display option 1.
    option1()
    input('Press Enter to see option 2.')
    # Display option 2.
    option2()
    input('Press Enter to see option 3.')
    # Display option 3.
    option3()
    input('Press Enter to see option 4.')
    # Display option 4.
    option4()

# The startup_message function displays the
# program's initial message on the screen.
def message():
    print('This program tells you options')
    print('how to use diswasher')
    print('There are 4 options to wash your dishes.')
    print()

# The option1 function displays the option

def option1():
    print('option 1: Press normal wash to wash dishes for 40 minutes')
    print()

# The option2 function displays the option

def option2():
    print('option 2: Press quick wash to wash dishes for 20 minutes')
    print()

# The option3 function displays the option
def option3():
    print('Option 3: Press heavy wash to wash dishes for 90 minutes')
    print('from the dryer.')
    print()

# The option4 function displays the option
def option4():
    print('Option 4: Press sanitize to sanitize the dishes for 60 minutes')


# Call the main function to begin the program.
main()

# %%
# !pip3 install ColabTurtle
from ColabTurtle.Turtle import *
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7641 sha256=49bf52c83538a49bc997b48c4d493eef4b62609cd4ce4abcfd3cb0bce7e6c2fa
#   Stored in directory: /root/.cache/pip/wheels/5b/86/e8/54f5c8c853606e3a3060bb2e60363cbed632374a12e0f33ffc
# Successfully built ColabTurtle
# ...

# %%
initializeTurtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %%
import ColabTurtle.Turtle as turtle

def triangle():
  for i in [1,2,3,4]:
    turtle.forward(100)
    turtle.left(120)

triangle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="486.603" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="486.603" y1="200.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="250.0" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="313.397" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.397" y1="200.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %%
for i in [1,2,3,4,5]:
  print(" *"*i)
# Out:
#  *
#  * *
#  * * *
#  * * * *
#  * * * * *
