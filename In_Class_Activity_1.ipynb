# %% [markdown]
# ##Instructions for In Class Activity 1
#
# You must find all errors in your scripts. But because you are communicating with a machine, not a person, you have to be exact: the computer cannot understand you at all if there are errors, bugs, in your code. Or the computer may do exactly what you wrote, but not what you meant to do.
#
# Add a comment to the file that describes what you did.
#
# Change the file name to "your name In Class Activity 1" and hand in these corrected Python scripts!

# %% [markdown]
# Question 1

# %%
x = 15
y = 5
z = 3
y=0
k = x / y
print(k)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-7a3189d9d5a0> in <cell line: 5>()
#       3 z = 3
#       4 y=0
# ----> 5 k = x / y
#       6 print(k)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Question 2

# %%
x = 10
y = 20
z = 30
  print(x, y, z)
# Out:
#   File "<ipython-input-2-b4b35a9db791>", line 4
#     print(x, y, z)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# Question 3

# %%
# This program converts miles to km

miles = 10
multiplier = 1.609344
km = miles * multplier
print(km)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ecc5195e62f4> in <cell line: 5>()
#       3 miles = 10
#       4 multiplier = 1.609344
# ----> 5 km = miles * multplier
#       6 print(km)
#
# NameError: name 'multplier' is not defined

# %% [markdown]
# Question 4

# %%
x = 1
y = 10
z = 2
t = 15
print((x * t) / (y / z)
print('Done')
# Out:
#   File "<ipython-input-7-a3780bd8aa53>", line 5
#     print((x * t) / (y / z)
#          ^
# SyntaxError: '(' was never closed

# %% [markdown]
# Question 5

# %%
fruit = "kiwi"
print(frut, frut, frut)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0b4c03768402> in <cell line: 2>()
#       1 fruit = "kiwi"
# ----> 2 print(frut, frut, frut)
#
# NameError: name 'frut' is not defined
